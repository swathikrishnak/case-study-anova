# %% [markdown]
# # Case Study on ANOV

# %% [markdown]
# # XYZ Company has offices in four different zones. The company wishes toinvestigate the following :● The mean sales generated by each zone

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Sales_data_zone_wise.csv")
data.head()
# Out:
#        Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0  Month - 1   1483525   1748451   1523308   2267260
# 1  Month - 2   1238428   1707421   2212113   1994341
# 2  Month - 3   1860771   2091194   1282374   1241600
# 3  Month - 4   1871571   1759617   2290580   2252681
# 4  Month - 5   1244922   1606010   1818334   1326062

# %%
data.isna().sum()
# Out:
# Month       0
# Zone - A    0
# Zone - B    0
# Zone - C    0
# Zone - D    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     29 non-null     object
#  1   Zone - A  29 non-null     int64
#  2   Zone - B  29 non-null     int64
#  3   Zone - C  29 non-null     int64
#  4   Zone - D  29 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# ## Investigating the mean sales generated by each zone.

# %%
data.describe()
# Out:
#            Zone - A      Zone - B      Zone - C      Zone - D
# count  2.900000e+01  2.900000e+01  2.900000e+01  2.900000e+01
# mean   1.540493e+06  1.755560e+06  1.772871e+06  1.842927e+06
# std    2.619401e+05  1.683899e+05  3.331937e+05  3.750165e+05
# min    1.128185e+06  1.527574e+06  1.237722e+06  1.234311e+06
# 25%    1.305972e+06  1.606010e+06  1.523308e+06  1.520406e+06
# 50%    1.534390e+06  1.740365e+06  1.767047e+06  1.854412e+06
# 75%    1.820196e+06  1.875658e+06  2.098463e+06  2.180416e+06
# max    2.004480e+06  2.091194e+06  2.290580e+06  2.364132e+06

# %% [markdown]
# We can see that the Means of the sales generated by each zone vary from eachother, especially that of Zone A.

# %% [markdown]
# # #Total sales generated by all the zones for each month.

# %%
Total_monthly_sale = data["Zone - A"] + data["Zone - B"] + data["Zone - C"] + data["Zone - D"]
data["Total_monthly_sale"] = Total_monthly_sale

# %%
data
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D  Total_monthly_sale
# 0    Month - 1   1483525   1748451   1523308   2267260             7022544
# 1    Month - 2   1238428   1707421   2212113   1994341             7152303
# 2    Month - 3   1860771   2091194   1282374   1241600             6475939
# 3    Month - 4   1871571   1759617   2290580   2252681             8174449
# 4    Month - 5   1244922   1606010   1818334   1326062             5995328
# 5    Month - 6   1534390   1573128   1751825   2292044             7151387
# 6    Month - 7   1820196   1992031   1786826   1688055             7287108
# 7    Month - 8   1625696   1665534   2161754   2363315             7816299
# 8    Month - 9   1652644   1873402   1755290   1422059             6703395
# 9   Month - 10   1852450   1913059   1754314   1608387             7128210
# 10  Month - 11   2004480   1740365   1317869   1970069             7032783
# ...

# %%
data["Total_monthly_sale"].mean()
# Out:
# 6911850.517241379

# %% [markdown]
# The mean total sale for all the months combined is 6911850.52

# %%
plt.figure(figsize=(17,8))
sns.barplot(data =data ,x = "Month", y = "Total_monthly_sale")
plt.title("Total Sales by Month", fontsize = 15, pad=10)
plt.xlabel("Months", fontsize=12)
plt.ylabel("Total Monthly Sale", fontsize = 12)
plt.xticks(rotation = 45)
plt.grid();

# %% [markdown]
# # Checking whether all the zones generate the same amount of sales.

# %% [markdown]
# NULL HYPOTHESIS, H0 :
#
# There is no significant difference among the zone wise sales.
#
# ALTERNATE HYPOTHESIS, Ha :
#
# At least one zone differs significantly from the other zones

# %%
from scipy.stats import f_oneway
data.head(1)
# Out:
#        Month  Zone - A  Zone - B  Zone - C  Zone - D  Total_monthly_sale
# 0  Month - 1   1483525   1748451   1523308   2267260             7022544

# %%
statistic, pvalue = f_oneway(data['Zone - A'], data['Zone - B'], data['Zone - C'],data['Zone - D'])
print(f"The F-statistic value is : \t{statistic:.3f}")
print(f"\nThe Calculated p value is : \t{pvalue:.3f}")

alpha = 0.05
# Out:
# The F-statistic value is : 	5.672
#
# The Calculated p value is : 	0.001

# %% [markdown]
# As the calculated pvalue is less than 0.05 (alpha), We'll reject the NULL Hypothesis and say that atleast one of the zones differs significantly from other zones in terms of sales.
#
# All the zones are not generating the same amount of sales.
